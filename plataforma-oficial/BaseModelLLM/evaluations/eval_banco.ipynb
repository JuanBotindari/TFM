# %%
import sys
import os

# Añadimos la raíz del repositorio al path para que 'LLM' se reconozca como un paquete
repo_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)

from LLM.clientes.banco import ClienteBanco

# %%
# Instanciamos para probar
bot_banco = ClienteBanco()
print(f"✅ Conectado a: {bot_banco.nombre_cliente}")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# ...
# 🤖 AGENTE ACTIVO: CLIENT-BANCO
# ...
#   🧠 LLM:        gemini-2.0-flash
#   📐 Embeddings: models/gemini-embedding-2
#
# 📚 Inicializando base de conocimiento vectorial...
# ☁️  [database_vector_banco] vacía — indexando desde Storage...
# 📥 Descargando PDFs de Storage [org-banco]...
#   📄 1.1_Identificacion.pdf (1 páginas)
#   📄 1.3_Roles_principales_.pdf (1 páginas)
#   📄 1778936310189_1.2_Descripcion_general.pdf (1 páginas)
#   📄 1778936488102_1.3_Roles_principales_.pdf (1 páginas)
#   📄 1779051124695_2.1_Productos_.pdf (1 páginas)
#   📄 1779052903491_2.1.1_Seguro_de_Vida_Riesgo_SVR_.pdf (1 páginas)
#   📄 1779053830301_2.1.2_Seguro_de_Hogar_SHG.pdf (1 páginas)
#   📄 1779053834124_2.1.3_Seguro_de_Proteccion_de_Pagos_SPP_.pdf (1 páginas)
#   📄 1779054019754_2.2_Componentes_de_una_poliza.pdf (1 páginas)
#   📄 1779054022802_2.3_Procesos.pdf (1 páginas)
# ...

# %%
# Hacemos la pregunta
pregunta = """

¿De qué tratan los documentos que tienes almacenados?


"""



print(f"Pregunta: {pregunta}\n")
print("Respuesta: ", end="")

# Como responder() devuelve los fragmentos poco a poco (yield), iteramos sobre ellos
for fragmento in bot_banco.responder(pregunta):
    print(fragmento, end="")
# Out:
# Pregunta:
#
# ¿De qué tratan los documentos que tienes almacenados?
#
#
#
#
# Respuesta:
# ────────────────────────────────────────────────────────────
# 🔎 TRAZA DE RAZONAMIENTO
# ────────────────────────────────────────────────────────────
#
#   Paso 1 — Pregunta recibida
#            ¿De qué tratan los documentos que tienes almacenados?
#
#   Paso 2 — Router de intención
#            El LLM clasifica si hace falta RAG, tablas, internet o respuesta directa.
#
#   Paso 3 — Intención seleccionada → RAG
#            Respuesta cruda del router:
# ...
