# %%
from langchain_community.llms import Ollama

# Conectamos con el servicio que está corriendo en tu Docker
llm = Ollama(model="phi3", base_url="http://localhost:11434")

# Prueba rápida para verificar conexión
response = llm.invoke("Hola, estamos listos para empezar el entrenamiento del TFM.")
print(response)
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_55940\775437646.py:4: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="phi3", base_url="http://localhost:11434")
# ¡Buenas! Parece que están listos para comenzar su programa de Entrenamiento Físico Total (TFM). Para ayudarlos a maximizar sus resultados y mantener un ritmo constante, es importante establecer metas claras y específsuit. Por favor proporcionen más detalles sobre lo que esperan lograr con el TFM para poder guiar mejor su entrenamiento personalizado.
#
# Ahora bien, aquí hay una estructura básica de un programa de ejercicio balanceado:
# ...

# %%
# !pip install -U langchain-community langchain ollama
# Out:
# ...
#      ---------------------------------------- 0.0/90.6 kB ? eta -:--:--
#      ---------------------------------------- 90.6/90.6 kB 2.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/43.1 kB ? eta -:--:--
#      ---------------------------------------- 43.1/43.1 kB 2.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.5 MB 40.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 31.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/112.5 kB ? eta -:--:--
#    ---------------------------------------- 112.5/112.5 kB 6.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 68.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/506.8 kB ? eta -:--:--
# ...
