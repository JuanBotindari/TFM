# %%
from LLM.clientes import ClienteEstudioContable

# %%
# Instanciamos para probar
LLM_estudio_contable = ClienteEstudioContable()
print(f"✅ Conectado a: {LLM_estudio_contable.nombre_cliente}")
# Out:
# ⚠️ _cargar_documentos() no implementado para 'Estudio Contable'. Sobreescribe este método.
# 🧠 Sistema de Estudio Contable inicializado y cargado en el modelo.
# ✅ Conectado a: Estudio Contable

# %%
pregunta = 'No que las mujeres mienten? '

for chunk in LLM_estudio_contable.responder(pregunta):
    print(chunk, end="")
# Out:
# Como experto en normativa fiscal para Estudio Contable, no tengo información sobre si "las mujeres" tienen una tendencia a mentir o cualquier comportamiento psicológico generalizado entre un grupo demográfico. Es importante evitar estereotipos y hacer afirmaciones basadas en datos objetivos y verificables. Si hay investigaciones específsuitas que sugieran diferencias de honestidad por género, sería mejor referirse a estudios científicos o legislación pertinente para obtener una comprensión más precisa del tema dentro del contexto legal y socialmente responsable.
#
# Si estás buscando información sobre la importancia de la transparencia e integridad en las empresas, puedo proporcionarte orientación basada en prácticas contables éticas y normativas fiscales que promueven honestidad y confiabilidad:
#
# ...
