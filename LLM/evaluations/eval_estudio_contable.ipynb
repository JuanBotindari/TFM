# %%
# %load_ext autoreload
# %autoreload 2
# autoreload hará que cada vez que cambies el .py, el Notebook se actualice solo.

import sys
import os

# Añadimos la raíz de la carpeta LLM al path para poder importar todo
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from clientes.estudio_contable import ClienteEstudioContable
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Instanciamos para probar
bot_contable = ClienteEstudioContable()
print(f"✅ Conectado a: {bot_contable.nombre_cliente}")
# Out:
# ✅ Conectado a: Estudio Contable

# %%
contexto = 'Eres un contador publico de argentina'
pregunta = 'Desde cuando existe ganancias? '
bot_contable.generar_respuesta( contexto + pregunta)
# Out:
# 'La historia del comercio y la economía en Argentina es rica e impresionante, con evidencia de actividad comercial que se remonta a miles de años atrás. Sin embargo, el concepto moderno de "ganancia" como lo entendemos hoy comenzó a tomar forma durante los siglos XIX y XX cuando la Argentina experimentó un rápido crecimiento económico debido al auge del cereal exportado en gran cantidad.\n\nLa industria textil, por ejemplo, se desarrolló significativamente desde finales del siglo XIX hasta principios del siglo XX como resultado de políticas proteccionistas que favorecieron la producción nacional sobre las importaciones extranjeras. Esto llevó a un aumento en el empleo y al desarrollo económico generalizado durante este período, conocido como "La Belle Époque" o época gloriosa argentina.\n\nSin embargo, es importante señalar que la ganancia no siempre ha sido distribuida de manera equitativa entre los sectores productivos del país. La historia de Argentina también está marcada por una
# ...
