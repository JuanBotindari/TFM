# %%
import sys
import os

# Añadimos la raíz de la carpeta LLM al path para poder importar todo
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from clientes.banco import ClienteBanco

# %%
# Instanciamos para probar
bot_banco = ClienteBanco()
print(f"✅ Conectado a: {bot_banco.nombre_cliente}")
# Out:
# ✅ Conectado a: Banco X
